# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('House_Rent_Dataset.csv')
data.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
data['Floor'].unique()
# Out:
# array(['Ground out of 2', '1 out of 3', '1 out of 2', 'Ground out of 1',
#        'Ground out of 4', '1 out of 4', '1 out of 1', 'Ground out of 3',
#        '2 out of 3', '4 out of 5', '2 out of 2', '2 out of 5',
#        '4 out of 14', '3 out of 3', '5 out of 5', '4 out of 4',
#        '7 out of 8', '2 out of 4', '3 out of 4', '1 out of 5',
#        '8 out of 5', 'Ground out of 6', '2 out of 1',
#        'Upper Basement out of 4', 'Ground out of 5', '3 out of 5',
#        '11 out of 19', '5 out of 10', '11 out of 14',
#        'Lower Basement out of 2', '2 out of 7', '4 out of 10',
#        '7 out of 10', '2 out of 13', '6 out of 7', '4 out of 7',
#        '14 out of 14', '43 out of 78', '2 out of 8', '13 out of 18',
#        '5 out of 12', '18 out of 24', '3 out of 7', '17 out of 31',
#        '11 out of 21', '7 out of 19', '14 out of 23', '9 out of 20',
#        'Upper Basement out of 9', '19 out of 24', '3 out of 21',
# ...

# %%
dup2 = data.query("Floor == 'Ground out of 18'")
dup2
# Out:
#        Posted On  BHK   Rent  Size             Floor   Area Type  \
# 1802  2022-06-20    3  30000  1893  Ground out of 18  Super Area
#
#      Area Locality       City Furnishing Status Tenant Preferred  Bathroom  \
# 1802    Begur Road  Bangalore    Semi-Furnished        Bachelors         4
#
#      Point of Contact
# 1802    Contact Agent

# %%
data.iloc[2553]
# Out:
# Posted On                                  2022-06-18
# BHK                                                 2
# Rent                                            20000
# Size                                              400
# Floor                                               3
# Area Type                                  Super Area
# Area Locality        Kasturba Niketan, Lajpat Nagar 2
# City                                            Delhi
# Furnishing Status                         Unfurnished
# Tenant Preferred                     Bachelors/Family
# Bathroom                                            1
# Point of Contact                        Contact Owner
# Name: 2553, dtype: object

# %%
data[['Floor_Available','Total_No_Of_Floors']] = data['Floor'].str.split('out of', expand = True)

# %%
data
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
data[data['Total_No_Of_Floors'].isnull()]
# Out:
#        Posted On  BHK   Rent  Size   Floor    Area Type  \
# 2553  2022-06-18    2  20000   400       3   Super Area
# 2883  2022-05-23    1  18000   450  Ground  Carpet Area
# 4490  2022-06-12    3  15000   900       1   Super Area
# 4560  2022-05-31    3  15000  1270       1  Carpet Area
#
#                                   Area Locality       City Furnishing Status  \
# 2553           Kasturba Niketan, Lajpat Nagar 2      Delhi       Unfurnished
# 2883  DDA Flat AD Block, Shalimar Bagh AD Block      Delhi         Furnished
# 4490                             Malakpet, NH 9  Hyderabad    Semi-Furnished
# 4560                                    Tarnaka  Hyderabad         Furnished
#
#       Tenant Preferred  Bathroom Point of Contact Floor_Available  \
# 2553  Bachelors/Family         1    Contact Owner               3
# 2883  Bachelors/Family         1    Contact Owner          Ground
# 4490  Bachelors/Family         3    Contact Owner               1
# ...

# %%
data.drop(columns=['Floor'],inplace=True)
data
# Out:
#        Posted On  BHK   Rent  Size    Area Type             Area Locality  \
# 0     2022-05-18    2  10000  1100   Super Area                    Bandel
# 1     2022-05-13    2  20000   800   Super Area  Phool Bagan, Kankurgachi
# 2     2022-05-16    2  17000  1000   Super Area   Salt Lake City Sector 2
# 3     2022-07-04    2  10000   800   Super Area               Dumdum Park
# 4     2022-05-09    2   7500   850  Carpet Area             South Dum Dum
# ...          ...  ...    ...   ...          ...                       ...
# 4741  2022-05-18    2  15000  1000  Carpet Area              Bandam Kommu
# 4742  2022-05-15    3  29000  2000   Super Area      Manikonda, Hyderabad
# 4743  2022-07-10    3  35000  1750  Carpet Area      Himayath Nagar, NH 7
# 4744  2022-07-06    3  45000  1500  Carpet Area                Gachibowli
# 4745  2022-05-04    2  15000  1000  Carpet Area           Suchitra Circle
#
#            City Furnishing Status  Tenant Preferred  Bathroom  \
# ...

# %%
data['Floor_Available'].unique()
# Out:
# array(['Ground ', '1 ', '2 ', '4 ', '3 ', '5 ', '7 ', '8 ',
#        'Upper Basement ', '11 ', 'Lower Basement ', '6 ', '14 ', '43 ',
#        '13 ', '18 ', '17 ', '9 ', '19 ', '60 ', '34 ', '12 ', '26 ',
#        '25 ', '53 ', '16 ', '10 ', '39 ', '32 ', '47 ', '28 ', '20 ',
#        '15 ', '65 ', '40 ', '37 ', '22 ', '21 ', '30 ', '35 ', '33 ',
#        '44 ', '41 ', '46 ', '27 ', '45 ', '48 ', '50 ', '24 ', '23 ',
#        '29 ', '49 ', '36 ', '76 ', '3', 'Ground', '1'], dtype=object)

# %%
#data['Floor Available'] = data['Floor Available'].replace({'Ground':0,'Upper Basement':-1,'Lower Basement':-2})
data['Floor_Available']=data['Floor_Available'].str.replace('Ground','0')
data['Floor_Available']=data['Floor_Available'].str.replace('Upper Basement','-1')
data['Floor_Available']=data['Floor_Available'].str.replace('Lower Basement','-2')
data
# Out:
#        Posted On  BHK   Rent  Size    Area Type             Area Locality  \
# 0     2022-05-18    2  10000  1100   Super Area                    Bandel
# 1     2022-05-13    2  20000   800   Super Area  Phool Bagan, Kankurgachi
# 2     2022-05-16    2  17000  1000   Super Area   Salt Lake City Sector 2
# 3     2022-07-04    2  10000   800   Super Area               Dumdum Park
# 4     2022-05-09    2   7500   850  Carpet Area             South Dum Dum
# ...          ...  ...    ...   ...          ...                       ...
# 4741  2022-05-18    2  15000  1000  Carpet Area              Bandam Kommu
# 4742  2022-05-15    3  29000  2000   Super Area      Manikonda, Hyderabad
# 4743  2022-07-10    3  35000  1750  Carpet Area      Himayath Nagar, NH 7
# 4744  2022-07-06    3  45000  1500  Carpet Area                Gachibowli
# 4745  2022-05-04    2  15000  1000  Carpet Area           Suchitra Circle
#
#            City Furnishing Status  Tenant Preferred  Bathroom  \
# ...

# %%
data['Floor_Available'].unique()
# Out:
# array(['0 ', '1 ', '2 ', '4 ', '3 ', '5 ', '7 ', '8 ', '-1 ', '11 ',
#        '-2 ', '6 ', '14 ', '43 ', '13 ', '18 ', '17 ', '9 ', '19 ', '60 ',
#        '34 ', '12 ', '26 ', '25 ', '53 ', '16 ', '10 ', '39 ', '32 ',
#        '47 ', '28 ', '20 ', '15 ', '65 ', '40 ', '37 ', '22 ', '21 ',
#        '30 ', '35 ', '33 ', '44 ', '41 ', '46 ', '27 ', '45 ', '48 ',
#        '50 ', '24 ', '23 ', '29 ', '49 ', '36 ', '76 ', '3', '0', '1'],
#       dtype=object)

# %%
data['Total_No_Of_Floors'].unique()
# Out:
# array([' 2', ' 3', ' 1', ' 4', ' 5', ' 14', ' 8', ' 6', ' 19', ' 10',
#        ' 7', ' 13', ' 78', ' 18', ' 12', ' 24', ' 31', ' 21', ' 23',
#        ' 20', ' 9', ' 22', ' 58', ' 16', ' 66', ' 48', ' 40', ' 44',
#        ' 42', ' 41', ' 60', ' 32', ' 30', ' 29', ' 89', ' 15', ' 11',
#        ' 28', ' 17', ' 45', ' 35', ' 75', ' 38', ' 51', ' 43', ' 25',
#        ' 27', ' 26', ' 76', ' 36', ' 37', ' 55', ' 68', ' 77', ' 50',
#        ' 59', ' 62', ' 39', ' 52', ' 54', ' 33', ' 46', ' 85', ' 71',
#        ' 81', ' 34', None], dtype=object)

# %%
dup2 = data.query("Total_No_Of_Floors == None", inplace=False)

# %%
dup2
# Out:
# Empty DataFrame
# Columns: [Posted On, BHK, Rent, Size, Area Type, Area Locality, City, Furnishing Status, Tenant Preferred, Bathroom, Point of Contact, Floor_Available, Total_No_Of_Floors]
# Index: []

# %%
data.isnull().any()
# Out:
# Posted On             False
# BHK                   False
# Rent                  False
# Size                  False
# Area Type             False
# Area Locality         False
# City                  False
# Furnishing Status     False
# Tenant Preferred      False
# Bathroom              False
# Point of Contact      False
# Floor_Available       False
# Total_No_Of_Floors     True
# dtype: bool

# %%
#a = data[data['Total_No_Of_Floors'].isnull()]
#print(a)
#b = data['Floor_Available']
# data.replace(a,b)

# data.iloc[2553]

# %%
data['Total_No_Of_Floors'].fillna("1000", inplace = True)

# %%
data.drop(data[data['Total_No_Of_Floors'] == "1000"].index, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4742 entries, 0 to 4745
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Posted On           4742 non-null   object
#  1   BHK                 4742 non-null   int64
#  2   Rent                4742 non-null   int64
#  3   Size                4742 non-null   int64
#  4   Area Type           4742 non-null   object
#  5   Area Locality       4742 non-null   object
#  6   City                4742 non-null   object
#  7   Furnishing Status   4742 non-null   object
#  8   Tenant Preferred    4742 non-null   object
#  9   Bathroom            4742 non-null   int64
#  10  Point of Contact    4742 non-null   object
#  11  Floor_Available     4742 non-null   object
#  12  Total_No_Of_Floors  4742 non-null   object
# dtypes: int64(4), object(9)
# memory usage: 518.7+ KB

# %%
data.iloc[2553]
# Out:
# Posted On                   2022-06-11
# BHK                                  3
# Rent                             10000
# Size                               100
# Area Type                  Carpet Area
# Area Locality            Krishna Nagar
# City                             Delhi
# Furnishing Status            Furnished
# Tenant Preferred      Bachelors/Family
# Bathroom                             2
# Point of Contact         Contact Owner
# Floor_Available                     1
# Total_No_Of_Floors                   4
# Name: 2554, dtype: object

# %%
data['Total_No_Of_Floors'] = data['Total_No_Of_Floors'].astype(int)
data['Floor_Available'] = data['Floor_Available'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4742 entries, 0 to 4745
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Posted On           4742 non-null   object
#  1   BHK                 4742 non-null   int64
#  2   Rent                4742 non-null   int64
#  3   Size                4742 non-null   int64
#  4   Area Type           4742 non-null   object
#  5   Area Locality       4742 non-null   object
#  6   City                4742 non-null   object
#  7   Furnishing Status   4742 non-null   object
#  8   Tenant Preferred    4742 non-null   object
#  9   Bathroom            4742 non-null   int64
#  10  Point of Contact    4742 non-null   object
#  11  Floor_Available     4742 non-null   int32
#  12  Total_No_Of_Floors  4742 non-null   int32
# dtypes: int32(2), int64(4), object(7)
# memory usage: 481.6+ KB

# %%
data['Posted On'].unique()
# Out:
# array(['2022-05-18', '2022-05-13', '2022-05-16', '2022-07-04',
#        '2022-05-09', '2022-04-29', '2022-06-21', '2022-06-07',
#        '2022-06-20', '2022-05-23', '2022-05-14', '2022-05-05',
#        '2022-06-01', '2022-05-17', '2022-06-09', '2022-07-02',
#        '2022-06-14', '2022-06-15', '2022-05-28', '2022-05-22',
#        '2022-06-18', '2022-06-25', '2022-06-22', '2022-05-21',
#        '2022-06-26', '2022-06-16', '2022-06-29', '2022-05-10',
#        '2022-05-12', '2022-06-03', '2022-05-31', '2022-06-10',
#        '2022-06-24', '2022-04-30', '2022-05-27', '2022-06-06',
#        '2022-05-20', '2022-05-26', '2022-07-03', '2022-04-23',
#        '2022-06-19', '2022-07-06', '2022-06-04', '2022-05-30',
#        '2022-06-08', '2022-05-03', '2022-05-07', '2022-06-27',
#        '2022-05-15', '2022-04-28', '2022-06-28', '2022-06-23',
#        '2022-06-13', '2022-05-04', '2022-04-25', '2022-05-06',
#        '2022-06-30', '2022-07-01', '2022-06-17', '2022-06-11',
# ...

# %%
data[['Year_of_Posting','Month_of_Posting','Day_of_The_Month']] = data['Posted On'].str.split('-', expand = True) 
data
# Out:
#        Posted On  BHK   Rent  Size    Area Type             Area Locality  \
# 0     2022-05-18    2  10000  1100   Super Area                    Bandel
# 1     2022-05-13    2  20000   800   Super Area  Phool Bagan, Kankurgachi
# 2     2022-05-16    2  17000  1000   Super Area   Salt Lake City Sector 2
# 3     2022-07-04    2  10000   800   Super Area               Dumdum Park
# 4     2022-05-09    2   7500   850  Carpet Area             South Dum Dum
# ...          ...  ...    ...   ...          ...                       ...
# 4741  2022-05-18    2  15000  1000  Carpet Area              Bandam Kommu
# 4742  2022-05-15    3  29000  2000   Super Area      Manikonda, Hyderabad
# 4743  2022-07-10    3  35000  1750  Carpet Area      Himayath Nagar, NH 7
# 4744  2022-07-06    3  45000  1500  Carpet Area                Gachibowli
# 4745  2022-05-04    2  15000  1000  Carpet Area           Suchitra Circle
#
#            City Furnishing Status  Tenant Preferred  Bathroom  \
# ...

# %%
data.drop(columns=['Posted On'],inplace=True)
data.drop(columns=['Point of Contact'],inplace=True)
data
# Out:
#       BHK   Rent  Size    Area Type             Area Locality       City  \
# 0       2  10000  1100   Super Area                    Bandel    Kolkata
# 1       2  20000   800   Super Area  Phool Bagan, Kankurgachi    Kolkata
# 2       2  17000  1000   Super Area   Salt Lake City Sector 2    Kolkata
# 3       2  10000   800   Super Area               Dumdum Park    Kolkata
# 4       2   7500   850  Carpet Area             South Dum Dum    Kolkata
# ...   ...    ...   ...          ...                       ...        ...
# 4741    2  15000  1000  Carpet Area              Bandam Kommu  Hyderabad
# 4742    3  29000  2000   Super Area      Manikonda, Hyderabad  Hyderabad
# 4743    3  35000  1750  Carpet Area      Himayath Nagar, NH 7  Hyderabad
# 4744    3  45000  1500  Carpet Area                Gachibowli  Hyderabad
# 4745    2  15000  1000  Carpet Area           Suchitra Circle  Hyderabad
#
#      Furnishing Status  Tenant Preferred  Bathroom  Floor_Available  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4742 entries, 0 to 4745
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BHK                 4742 non-null   int64
#  1   Rent                4742 non-null   int64
#  2   Size                4742 non-null   int64
#  3   Area Type           4742 non-null   object
#  4   Area Locality       4742 non-null   object
#  5   City                4742 non-null   object
#  6   Furnishing Status   4742 non-null   object
#  7   Tenant Preferred    4742 non-null   object
#  8   Bathroom            4742 non-null   int64
#  9   Floor_Available     4742 non-null   int32
#  10  Total_No_Of_Floors  4742 non-null   int32
#  11  Year_of_Posting     4742 non-null   object
#  12  Month_of_Posting    4742 non-null   object
#  13  Day_of_The_Month    4742 non-null   object
# dtypes: int32(2), int64(4), object(8)
# memory usage: 518.7+ KB

# %%
data['Year_of_Posting'] = data['Year_of_Posting'].astype(int)
data['Month_of_Posting'] = data['Month_of_Posting'].astype(int)
data['Day_of_The_Month'] = data['Day_of_The_Month'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4742 entries, 0 to 4745
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BHK                 4742 non-null   int64
#  1   Rent                4742 non-null   int64
#  2   Size                4742 non-null   int64
#  3   Area Type           4742 non-null   object
#  4   Area Locality       4742 non-null   object
#  5   City                4742 non-null   object
#  6   Furnishing Status   4742 non-null   object
#  7   Tenant Preferred    4742 non-null   object
#  8   Bathroom            4742 non-null   int64
#  9   Floor_Available     4742 non-null   int32
#  10  Total_No_Of_Floors  4742 non-null   int32
#  11  Year_of_Posting     4742 non-null   int32
#  12  Month_of_Posting    4742 non-null   int32
#  13  Day_of_The_Month    4742 non-null   int32
# dtypes: int32(5), int64(4), object(5)
# memory usage: 463.1+ KB

# %%
data
# Out:
#       BHK   Rent  Size    Area Type             Area Locality       City  \
# 0       2  10000  1100   Super Area                    Bandel    Kolkata
# 1       2  20000   800   Super Area  Phool Bagan, Kankurgachi    Kolkata
# 2       2  17000  1000   Super Area   Salt Lake City Sector 2    Kolkata
# 3       2  10000   800   Super Area               Dumdum Park    Kolkata
# 4       2   7500   850  Carpet Area             South Dum Dum    Kolkata
# ...   ...    ...   ...          ...                       ...        ...
# 4741    2  15000  1000  Carpet Area              Bandam Kommu  Hyderabad
# 4742    3  29000  2000   Super Area      Manikonda, Hyderabad  Hyderabad
# 4743    3  35000  1750  Carpet Area      Himayath Nagar, NH 7  Hyderabad
# 4744    3  45000  1500  Carpet Area                Gachibowli  Hyderabad
# 4745    2  15000  1000  Carpet Area           Suchitra Circle  Hyderabad
#
#      Furnishing Status  Tenant Preferred  Bathroom  Floor_Available  \
# ...

# %%
dat = data.loc[(data['Size'] > 2000) & (data['Size'] < 2700) & (data['Rent'] > 3000000)]
dat
# Out:
#       BHK     Rent  Size    Area Type Area Locality       City  \
# 1837    3  3500000  2500  Carpet Area  Marathahalli  Bangalore
#
#      Furnishing Status Tenant Preferred  Bathroom  Floor_Available  \
# 1837    Semi-Furnished        Bachelors         3                4
#
#       Total_No_Of_Floors  Year_of_Posting  Month_of_Posting  Day_of_The_Month
# 1837                   4             2022                 6                 8

# %%
data.drop([1837], axis = 0, inplace =True)
#data.drop((data['Size'] == 2500) & (data['Rent'] == 3500000), axis = 0, inplace =True)

# %%
dat = data.loc[(data['Size'] > 2000) & (data['Size'] < 2700) & (data['Rent'] > 3000000)]
dat
# Out:
# Empty DataFrame
# Columns: [BHK, Rent, Size, Area Type, Area Locality, City, Furnishing Status, Tenant Preferred, Bathroom, Floor_Available, Total_No_Of_Floors, Year_of_Posting, Month_of_Posting, Day_of_The_Month]
# Index: []

# %%
sns.set_theme()
sns.catplot(data = data, x="Area Type", kind = 'count', hue='City')

# %%
data.plot(x = 'Size', y = 'Rent', kind = 'scatter')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
correlation_data = data.corr()
axis_corr = sns.heatmap(
correlation_data,
vmin = -1, vmax = 1, center = 0,
cmap = sns.diverging_palette(50, 500, n = 500),
square = True
)
plt.show()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_9740\3394236273.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_data = data.corr()

# %%
sns.barplot(x ="City", y = "Rent", data = data, hue = "Area Type")
# Out:
# <AxesSubplot: xlabel='City', ylabel='Rent'>

# %%
sns.barplot(x ="City", y = "Rent", data = data)
# Out:
# <AxesSubplot: xlabel='City', ylabel='Rent'>

# %%
data['Tenant Preferred'].unique()
# Out:
# array(['Bachelors/Family', 'Bachelors', 'Family'], dtype=object)

# %%
favbev = pd.get_dummies (data['Area Type'])
favbev1 = pd.get_dummies (data['City'])
favbev2 = pd.get_dummies (data['Tenant Preferred'])
favbev3 = pd.get_dummies (data['Furnishing Status'])

data.drop(columns=['Area Type','City','Tenant Preferred','Furnishing Status','Area Locality'],inplace=True)

data = pd.concat([favbev, data], axis = 1)
data = pd.concat([favbev1, data], axis = 1)
data = pd.concat([favbev2, data], axis = 1)
data = pd.concat([favbev3, data], axis = 1)
data
# Out:
#       Furnished  Semi-Furnished  Unfurnished  Bachelors  Bachelors/Family  \
# 0             0               0            1          0                 1
# 1             0               1            0          0                 1
# 2             0               1            0          0                 1
# 3             0               0            1          0                 1
# 4             0               0            1          1                 0
# ...         ...             ...          ...        ...               ...
# 4741          0               1            0          0                 1
# 4742          0               1            0          0                 1
# 4743          0               1            0          0                 1
# 4744          0               1            0          0                 0
# 4745          0               0            1          1                 0
#
#       Family  Bangalore  Chennai  Delhi  Hyderabad  ...  Super Area  BHK  \
# ...

# %%
data['Size'].max()
# Out:
# 8000

# %%
data = data.drop(columns='Day_of_The_Month')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4741 entries, 0 to 4745
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Furnished           4741 non-null   uint8
#  1   Semi-Furnished      4741 non-null   uint8
#  2   Unfurnished         4741 non-null   uint8
#  3   Bachelors           4741 non-null   uint8
#  4   Bachelors/Family    4741 non-null   uint8
#  5   Family              4741 non-null   uint8
#  6   Bangalore           4741 non-null   uint8
#  7   Chennai             4741 non-null   uint8
#  8   Delhi               4741 non-null   uint8
#  9   Hyderabad           4741 non-null   uint8
#  10  Kolkata             4741 non-null   uint8
#  11  Mumbai              4741 non-null   uint8
#  12  Built Area          4741 non-null   uint8
#  13  Carpet Area         4741 non-null   uint8
#  14  Super Area          4741 non-null   uint8
#  15  BHK                 4741 non-null   int64
# ...

# %%
# Building our Machine learning Model

from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
y = data['Rent']
x  = data.drop(columns = ['Rent'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x , y , test_size = 0.3, random_state = 20)

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test, y_test)
# Out:
# 0.5626262820289709

# %%
import pickle
pickle.dump(reg,open('randompicklet.pkl','wb'))
